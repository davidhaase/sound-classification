# %%
import os
from audioutils import AudioSplitter, Predictor, greek, arabic, turkish, persian, russian
# Out:
# Using TensorFlow backend.

# %%
model_path = 'my_model.h5'
test_dir  = '/Volumes/LaCie Rose Gold 2TB/Datasets/Audio/20_Seconds/Test_20/'
train_file = '/Volumes/LaCie Rose Gold 2TB/Datasets/Features/feat_003/Train_Feature_Pickles/extracted.pkl'
# test_dir = '/Users/davidhaase/Desktop/voicememos/'


Asml = Predictor(model_path)
Asml.build_model_from_features(train_file)

# Asml.build_model()
